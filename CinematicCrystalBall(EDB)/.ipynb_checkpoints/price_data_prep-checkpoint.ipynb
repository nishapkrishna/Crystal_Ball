# %%
import pandas as pd

# %%
file = "RDC_InventoryCoreMetrics_Zip_Hist.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(file)
df.head()
# Out:
# C:\Users\naras\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       Month  ZipCode          ZipName Footnote  Median Listing Price  \
# 0  9/1/2017   1001.0       Agawam, MA      NaN              213700.0
# 1  9/1/2017   1002.0      Amherst, MA      NaN              358500.0
# 2  9/1/2017   1005.0        Barre, MA      NaN              251300.0
# 3  9/1/2017   1007.0  Belchertown, MA      NaN              333600.0
# 4  9/1/2017   1008.0    Blandford, MA      NaN              186200.0
#
#    Median Listing Price M/M  Median Listing Price Y/Y  Active Listing Count   \
# 0                   -0.0387                   -0.0286                   52.0
# 1                   -0.0465                    0.0913                  110.0
# 2                   -0.0408                    0.1100                   24.0
# 3                   -0.0039                    0.1120                   82.0
# 4                    0.0081                   -0.0432                   14.0
#
#    Active Listing Count M/M  Active Listing Count Y/Y  ...  \
# 0                    0.0612                   -0.2571  ...
# 1                   -0.0678                   -0.0351  ...
# 2                    0.1429                   -0.1724  ...
# 3                   -0.0353                   -0.0889  ...
# 4                    0.0000                   -0.2222  ...
#
#    Pending Listing Count Y/Y  Avg Listing Price  Avg Listing Price M/M  \
# 0                        0.0           248200.0                -0.0028
# 1                        NaN           444400.0                 0.0018
# 2                        NaN           250900.0                -0.0260
# 3                        NaN           331500.0                -0.0140
# 4                        0.0           257300.0                 0.0235
#
#    Avg Listing Price Y/Y  Total Listing Count  Total Listing Count M/M  \
# 0                 0.0973                 53.0                   0.0600
# 1                 0.2396                110.0                  -0.0678
# 2                 0.0321                 24.0                   0.1429
# 3                 0.0805                 82.0                  -0.0353
# 4                -0.3675                 15.0                   0.0000
#
#    Total Listing Count Y/Y  Pending Ratio  Pending Ratio M/M  \
# 0                  -0.2535         0.0192            -0.0012
# 1                  -0.0351         0.0000             0.0000
# 2                  -0.1724         0.0000             0.0000
# 3                  -0.0889         0.0000             0.0000
# 4                  -0.2105         0.0714             0.0000
#
#    Pending Ratio Y/Y
# 0             0.0049
# 1             0.0000
# 2             0.0000
# 3             0.0000
# 4             0.0159
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Month', 'ZipCode', 'ZipName', 'Footnote', 'Median Listing Price',
#        'Median Listing Price M/M', 'Median Listing Price Y/Y',
#        'Active Listing Count ', 'Active Listing Count M/M',
#        'Active Listing Count Y/Y', 'Days on Market ', 'Days on Market M/M',
#        'Days on Market Y/Y', 'New Listing Count ', 'New Listing Count M/M',
#        'New Listing Count Y/Y', 'Price Increase Count ',
#        'Price Increase Count M/M', 'Price Increase Count Y/Y',
#        'Price Decrease Count ', 'Price Decrease Count M/M',
#        'Price Decrease Count Y/Y', 'Pending Listing Count ',
#        'Pending Listing Count M/M', 'Pending Listing Count Y/Y',
#        'Avg Listing Price', 'Avg Listing Price M/M', 'Avg Listing Price Y/Y',
#        'Total Listing Count', 'Total Listing Count M/M',
#        'Total Listing Count Y/Y', 'Pending Ratio', 'Pending Ratio M/M',
#        'Pending Ratio Y/Y'],
#       dtype='object')

# %%
zip_data = df.loc[:, ["Month", "ZipCode", "ZipName","Median Listing Price", 
                                    "Active Listing Count ", "Avg Listing Price"]]
zip_data.head()
# Out:
#       Month  ZipCode          ZipName  Median Listing Price  \
# 0  9/1/2017   1001.0       Agawam, MA              213700.0
# 1  9/1/2017   1002.0      Amherst, MA              358500.0
# 2  9/1/2017   1005.0        Barre, MA              251300.0
# 3  9/1/2017   1007.0  Belchertown, MA              333600.0
# 4  9/1/2017   1008.0    Blandford, MA              186200.0
#
#    Active Listing Count   Avg Listing Price
# 0                   52.0           248200.0
# 1                  110.0           444400.0
# 2                   24.0           250900.0
# 3                   82.0           331500.0
# 4                   14.0           257300.0

# %%
zip_data[['City','State']] = zip_data.ZipName.str.split(",",expand=True,)
zip_data.head()
# Out:
#       Month  ZipCode          ZipName  Median Listing Price  \
# 0  9/1/2017   1001.0       Agawam, MA              213700.0
# 1  9/1/2017   1002.0      Amherst, MA              358500.0
# 2  9/1/2017   1005.0        Barre, MA              251300.0
# 3  9/1/2017   1007.0  Belchertown, MA              333600.0
# 4  9/1/2017   1008.0    Blandford, MA              186200.0
#
#    Active Listing Count   Avg Listing Price         City State
# 0                   52.0           248200.0       Agawam    MA
# 1                  110.0           444400.0      Amherst    MA
# 2                   24.0           250900.0        Barre    MA
# 3                   82.0           331500.0  Belchertown    MA
# 4                   14.0           257300.0    Blandford    MA

# %%
zip_data['State'] = zip_data['State'].str.replace(' ', '')
zip_data.head()
# Out:
#       Month  ZipCode          ZipName  Median Listing Price  \
# 0  9/1/2017   1001.0       Agawam, MA              213700.0
# 1  9/1/2017   1002.0      Amherst, MA              358500.0
# 2  9/1/2017   1005.0        Barre, MA              251300.0
# 3  9/1/2017   1007.0  Belchertown, MA              333600.0
# 4  9/1/2017   1008.0    Blandford, MA              186200.0
#
#    Active Listing Count   Avg Listing Price         City State
# 0                   52.0           248200.0       Agawam    MA
# 1                  110.0           444400.0      Amherst    MA
# 2                   24.0           250900.0        Barre    MA
# 3                   82.0           331500.0  Belchertown    MA
# 4                   14.0           257300.0    Blandford    MA

# %%
zip_data[['Month1','Day', 'Year']] = zip_data.Month.str.split("/",expand=True,)
zip_data.head()
# Out:
#       Month  ZipCode          ZipName  Median Listing Price  \
# 0  9/1/2017   1001.0       Agawam, MA              213700.0
# 1  9/1/2017   1002.0      Amherst, MA              358500.0
# 2  9/1/2017   1005.0        Barre, MA              251300.0
# 3  9/1/2017   1007.0  Belchertown, MA              333600.0
# 4  9/1/2017   1008.0    Blandford, MA              186200.0
#
#    Active Listing Count   Avg Listing Price         City State Month1 Day  \
# 0                   52.0           248200.0       Agawam    MA      9   1
# 1                  110.0           444400.0      Amherst    MA      9   1
# 2                   24.0           250900.0        Barre    MA      9   1
# 3                   82.0           331500.0  Belchertown    MA      9   1
# 4                   14.0           257300.0    Blandford    MA      9   1
#
#    Year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
agg = {'Active Listing Count ': ['sum'], 'Avg Listing Price': ['mean']}

# %%
State_data_df = zip_data.groupby(['State', 'Year']).agg(agg).reset_index()
State_data_df.head(5)
# Out:
#   State  Year Active Listing Count  Avg Listing Price
#                                 sum              mean
# 0    AK  2012               26495.0     301629.249012
# 1    AK  2013               36704.0     307276.640420
# 2    AK  2014               33971.0     314421.354167
# 3    AK  2015               32011.0     325759.541985
# 4    AK  2016               34157.0     326024.494949

# %%
State_data_df.columns = ['State', 'Year', 'Active Listing Count', 'Avg Listing Price']
State_data_df.head()
# Out:
#   State  Year  Active Listing Count  Avg Listing Price
# 0    AK  2012               26495.0      301629.249012
# 1    AK  2013               36704.0      307276.640420
# 2    AK  2014               33971.0      314421.354167
# 3    AK  2015               32011.0      325759.541985
# 4    AK  2016               34157.0      326024.494949

# %%
State_data_df = State_data_df.sort_values(['Year', 'State'])
State_data_df.head(20)
# Out:
#     State  Year  Active Listing Count  Avg Listing Price
# 0      AK  2012               26495.0      301629.249012
# 6      AL  2012              312875.0      193571.345029
# 12     AR  2012              148267.0      190982.723735
# 18     AZ  2012              255573.0      274091.164454
# 24     CA  2012              815351.0      584730.605448
# 30     CO  2012              294914.0      448192.827201
# 36     CT  2012              242581.0      497561.363636
# 42     DC  2012               16116.0      626075.657895
# 48     DE  2012               73950.0      301246.851385
# 54     FL  2012             1316402.0      321932.092813
# 60     GA  2012              658385.0      234588.318431
# 66     HI  2012               58918.0      845203.890160
# 72     IA  2012              120401.0      181770.399374
# 78     ID  2012              111745.0      306117.934783
# 84     IL  2012              699661.0      225672.901395
# 90     IN  2012              342352.0      161708.534252
# 96     KS  2012              110513.0      190897.339056
# 102    KY  2012              193352.0      193294.504792
# 108    LA  2012              149574.0      211846.016484
# 114    MA  2012              271769.0      508761.221176

# %%
State_data_df.to_csv('State_housing_price_agg.csv', encoding='utf-8', index=False)
